# %%
from utils import plip_2d_interactions
from plip.structure.preparation import PDBComplex

my_mol = PDBComplex()
my_mol.load_pdb("./example_pdb/7tll.pdb")
my_id = str(my_mol).split("\n")[1]

plip_2d_interactions("./example_pdb/7tll.pdb", my_id, save_files=True)
plip_2d_interactions("./example_pdb/7tll.pdb", my_id, save_files=False)
# Out:
# 2024-03-11 10:51:54,901 [WARNING] [preparation.py:1418] plip.structure.preparation: no polar hydrogens will be assigned (make sure your structure contains hydrogens)
# 2024-03-11 10:51:56,517 [WARNING] [preparation.py:1418] plip.structure.preparation: no polar hydrogens will be assigned (make sure your structure contains hydrogens)
# [10:51:57] Molecule does not have explicit Hs. Consider calling AddHs()
# 2024-03-11 10:52:00,600 [WARNING] [preparation.py:1418] plip.structure.preparation: no polar hydrogens will be assigned (make sure your structure contains hydrogens)
# [10:52:01] Molecule does not have explicit Hs. Consider calling AddHs()
