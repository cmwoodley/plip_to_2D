# %%
from utils import plip_2d_interactions
from plip.structure.preparation import PDBComplex

my_mol = PDBComplex()
my_mol.load_pdb("./example_pdb/7tll.pdb")
my_id = str(my_mol).split("\n")[1]

plip_2d_interactions("./example_pdb/7tll.pdb", my_id, save_files=True)
plip_2d_interactions("./example_pdb/7tll.pdb", my_id, save_files=False)
# Out:
# 2024-03-05 10:53:54,994 [WARNING] [preparation.py:1418] plip.structure.preparation: no polar hydrogens will be assigned (make sure your structure contains hydrogens)
# 2024-03-05 10:53:58,822 [WARNING] [preparation.py:1418] plip.structure.preparation: no polar hydrogens will be assigned (make sure your structure contains hydrogens)
# [10:54:00] Molecule does not have explicit Hs. Consider calling AddHs()
# 2024-03-05 10:54:07,664 [WARNING] [preparation.py:1418] plip.structure.preparation: no polar hydrogens will be assigned (make sure your structure contains hydrogens)
# [10:54:08] Molecule does not have explicit Hs. Consider calling AddHs()
